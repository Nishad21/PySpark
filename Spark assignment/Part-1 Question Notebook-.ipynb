# %%
from pyspark.sql import DataFrame, SparkSession

spark = SparkSession \
       .builder \
       .appName("iot_devices") \
       .getOrCreate()

spark
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://Vamsi:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.3.0</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>iot_devices</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %% [markdown]
# ## 1.Read the data into a Dataframe.

# %%
path = "iot_devices.json"
iotDF = spark.read.json(path)

# %%
iotDF.show(5, False)
# Out:
# +-------------+---------+----+----+-------------+---------+---------------------+--------+-------------+--------+------+---------+-------+----+-------------+
# |battery_level|c02_level|cca2|cca3|cn           |device_id|device_name          |humidity|ip           |latitude|lcd   |longitude|scale  |temp|timestamp    |
# +-------------+---------+----+----+-------------+---------+---------------------+--------+-------------+--------+------+---------+-------+----+-------------+
# |8            |868      |US  |USA |United States|1        |meter-gauge-1xbYRYcj |51      |68.161.225.1 |38.0    |green |-97.0    |Celsius|34  |1458444054093|
# |7            |1473     |NO  |NOR |Norway       |2        |sensor-pad-2n2Pea    |70      |213.161.254.1|62.47   |red   |6.15     |Celsius|11  |1458444054119|
# |2            |1556     |IT  |ITA |Italy        |3        |device-mac-36TWSKiT  |44      |88.36.5.1    |42.83   |red   |12.83    |Celsius|19  |1458444054120|
# |6            |1080     |US  |USA |United States|4        |sensor-pad-4mzWkz    |32      |66.39.173.154|44.06   |yellow|-121.32  |Celsius|28  |1458444054121|
# |4            |931      |PH  |PHL |Philippines  |5        |therm-stick-5gimpUrBB|62      |203.82.41.9  |14.58   |green |120.97   |Celsius|25  |1458444054122|
# +-------------+---------+----+----+-------------+---------+---------------------+--------+-------------+--------+------+---------+-------+----+-------------+
# only showing top 5 rows

# %%
# extracting number of rows from the Dataframe
row = iotDF.count()
   
# extracting number of columns from the Dataframe
col = len(iotDF.columns)
 
# printing
print(f'Dimension of the Dataframe is: {(row,col)}')
print(f'Number of Rows are: {row}')
print(f'Number of Columns are: {col}')
# Out:
# Dimension of the Dataframe is: (198164, 15)
# Number of Rows are: 198164
# Number of Columns are: 15

# %%
iotDF.printSchema()
# Out:
# root
#  |-- battery_level: long (nullable = true)
#  |-- c02_level: long (nullable = true)
#  |-- cca2: string (nullable = true)
#  |-- cca3: string (nullable = true)
#  |-- cn: string (nullable = true)
#  |-- device_id: long (nullable = true)
#  |-- device_name: string (nullable = true)
#  |-- humidity: long (nullable = true)
#  |-- ip: string (nullable = true)
#  |-- latitude: double (nullable = true)
#  |-- lcd: string (nullable = true)
#  |-- longitude: double (nullable = true)
#  |-- scale: string (nullable = true)
#  |-- temp: long (nullable = true)
#  |-- timestamp: long (nullable = true)

# %% [markdown]
# ## 2.Convert the Dataframe into a temporary view called iot.

# %%
iotDF.createOrReplaceTempView("iot")

# %% [markdown]
# ## 3.Count how many devices are there from each country and display the output.

# %%
devicesfromcountryDF = spark.sql("SELECT cn, COUNT(device_name) FROM iot GROUP BY cn")

# %%
# extracting number of rows from the Dataframe
row = devicesfromcountryDF.count()
   
# extracting number of columns from the Dataframe
col = len(devicesfromcountryDF.columns)
 
# printing
print(f'Dimension of the Dataframe is: {(row,col)}')
print(f'Number of Rows are: {row}')
print(f'Number of Columns are: {col}')
# Out:
# Dimension of the Dataframe is: (209, 2)
# Number of Rows are: 209
# Number of Columns are: 2

# %%
devicesfromcountryDF.show(209, False)
# Out:
# +--------------------------------+------------------+
# |cn                              |count(device_name)|
# +--------------------------------+------------------+
# |Russia                          |5989              |
# |Paraguay                        |32                |
# |Anguilla                        |7                 |
# |Macao                           |33                |
# |U.S. Virgin Islands             |51                |
# |Yemen                           |19                |
# |British Indian Ocean Territory  |2                 |
# |Senegal                         |25                |
# |Sweden                          |2880              |
# |Republic of Korea               |11879             |
# |Philippines                     |681               |
# |Jersey                          |34                |
# |Singapore                       |1076              |
# |Malaysia                        |726               |
# |Fiji                            |11                |
# |Turkey                          |681               |
# |Malawi                          |9                 |
# |Åland                           |20                |
# |Iraq                            |7                 |
# |Germany                         |7942              |
# |Northern Mariana Islands        |9                 |
# |Cambodia                        |43                |
# |Afghanistan                     |19                |
# |Maldives                        |11                |
# |Rwanda                          |6                 |
# |Ivory Coast                     |10                |
# |Sudan                           |32                |
# |France                          |5305              |
# |Turks and Caicos Islands        |1                 |
# |Greece                          |418               |
# |Hashemite Kingdom of Jordan     |46                |
# |Kosovo                          |7                 |
# |Sri Lanka                       |65                |
# |Taiwan                          |2128              |
# |Dominica                        |26                |
# |British Virgin Islands          |6                 |
# |Algeria                         |34                |
# |Togo                            |7                 |
# |Argentina                       |978               |
# |Belgium                         |666               |
# |Angola                          |28                |
# |East Timor                      |3                 |
# |Ecuador                         |242               |
# |Qatar                           |58                |
# |Lesotho                         |5                 |
# |Madagascar                      |15                |
# |Albania                         |32                |
# |Finland                         |694               |
# |New Caledonia                   |18                |
# |Nicaragua                       |47                |
# |Ghana                           |30                |
# |Guernsey                        |8                 |
# |Peru                            |116               |
# |Sierra Leone                    |4                 |
# |Benin                           |3                 |
# |United States                   |68545             |
# |China                           |14455             |
# |India                           |1867              |
# |Bahamas                         |18                |
# |Belarus                         |123               |
# |Malta                           |63                |
# |Kuwait                          |120               |
# |Marshall Islands                |3                 |
# |Chile                           |371               |
# |Puerto Rico                     |253               |
# |Tajikistan                      |4                 |
# |Martinique                      |6                 |
# |Cayman Islands                  |26                |
# |Isle of Man                     |8                 |
# |Croatia                         |193               |
# |Nigeria                         |58                |
# |Bolivia                         |108               |
# |Andorra                         |4                 |
# |Italy                           |2915              |
# |Suriname                        |10                |
# |Réunion                         |9                 |
# |Norway                          |1487              |
# |Turkmenistan                    |3                 |
# |Spain                           |2310              |
# |Cuba                            |15                |
# |Mauritania                      |7                 |
# |Guadeloupe                      |12                |
# |Denmark                         |1190              |
# |Bangladesh                      |153               |
# |Barbados                        |38                |
# |Iran                            |336               |
# |Curaçao                         |36                |
# |Ireland                         |446               |
# |Liechtenstein                   |15                |
# |Congo                           |8                 |
# |Thailand                        |947               |
# |Swaziland                       |11                |
# |Laos                            |7                 |
# |Bhutan                          |8                 |
# |Monaco                          |12                |
# |Morocco                         |88                |
# |Panama                          |127               |
# |Hong Kong                       |1428              |
# |Ukraine                         |1448              |
# |Venezuela                       |190               |
# |Israel                          |710               |
# |Iceland                         |81                |
# |Saint Kitts and Nevis           |23                |
# |French Polynesia                |20                |
# |Oman                            |25                |
# |Cyprus                          |93                |
# |Palestine                       |25                |
# |Gibraltar                       |9                 |
# |Uruguay                         |117               |
# |Mexico                          |1214              |
# |Aruba                           |8                 |
# |Estonia                         |190               |
# |Montenegro                      |14                |
# |Georgia                         |95                |
# |Zimbabwe                        |27                |
# |Indonesia                       |811               |
# |Saint Vincent and the Grenadines|11                |
# |Guatemala                       |63                |
# |Mongolia                        |39                |
# |Guam                            |32                |
# |Republic of the Congo           |3                 |
# |Azerbaijan                      |49                |
# |Libya                           |16                |
# |Grenada                         |12                |
# |Sint Maarten                    |7                 |
# |Armenia                         |34                |
# |Tunisia                         |31                |
# |Liberia                         |2                 |
# |Syria                           |5                 |
# |Honduras                        |50                |
# |Trinidad and Tobago             |28                |
# |Saudi Arabia                    |136               |
# |Uganda                          |33                |
# |Namibia                         |30                |
# |Switzerland                     |1321              |
# |Zambia                          |7                 |
# |Latvia                          |358               |
# |Jamaica                         |44                |
# |United Arab Emirates            |123               |
# |Brunei                          |19                |
# |Saint Lucia                     |6                 |
# |Canada                          |6041              |
# |Kyrgyzstan                      |43                |
# |Macedonia                       |75                |
# |Faroe Islands                   |14                |
# |Uzbekistan                      |34                |
# |Czech Republic                  |1507              |
# |Mozambique                      |22                |
# |Brazil                          |3224              |
# |Belize                          |13                |
# |Gambia                          |7                 |
# |Kenya                           |96                |
# |Lebanon                         |72                |
# |Slovenia                        |281               |
# |Antigua and Barbuda             |60                |
# |Dominican Republic              |24                |
# |Japan                           |12100             |
# |Botswana                        |12                |
# |Tanzania                        |53                |
# |Luxembourg                      |88                |
# |New Zealand                     |457               |
# |                                |1810              |
# |Bosnia and Herzegovina          |106               |
# |Haiti                           |12                |
# |Poland                          |2744              |
# |Republic of Moldova             |79                |
# |Portugal                        |450               |
# |Australia                       |3119              |
# |Cameroon                        |29                |
# |Papua New Guinea                |16                |
# |Romania                         |1151              |
# |Bulgaria                        |1334              |
# |Austria                         |1462              |
# |Nepal                           |33                |
# |Republic of Lithuania           |312               |
# |Egypt                           |241               |
# |Costa Rica                      |116               |
# |Kazakhstan                      |228               |
# |El Salvador                     |60                |
# |Serbia                          |255               |
# |South Africa                    |560               |
# |Burkina Faso                    |24                |
# |Bermuda                         |53                |
# |Bahrain                         |55                |
# |Colombia                        |423               |
# |Hungary                         |772               |
# |Pakistan                        |256               |
# |Vatican City                    |1                 |
# |Vanuatu                         |10                |
# |Mauritius                       |37                |
# |United Kingdom                  |6486              |
# |Vietnam                         |246               |
# |Slovak Republic                 |305               |
# |Netherlands                     |2488              |
# |Mali                            |11                |
# |Guyana                          |5                 |
# |Federated States of Micronesia  |3                 |
# |Seychelles                      |4                 |
# |Cook Islands                    |3                 |
# |Greenland                       |2                 |
# |Tonga                           |1                 |
# |San Marino                      |3                 |
# |American Samoa                  |3                 |
# |Gabon                           |1                 |
# |Guinea                          |1                 |
# |Samoa                           |1                 |
# |Falkland Islands                |1                 |
# |Solomon Islands                 |2                 |
# |Saint Martin                    |1                 |
# +--------------------------------+------------------+

# %% [markdown]
# ## 4.Display all the countries whose carbon dioxide level is more than 1400. Sort the output in descending order.

# %%
countriesCO2DF = spark.sql("SELECT cn, COUNT(c02_level) FROM iot WHERE c02_level > 1400 GROUP BY cn ORDER BY COUNT(c02_level) DESC")

# %%
# extracting number of rows from the Dataframe
row = countriesCO2DF.count()
   
# extracting number of columns from the Dataframe
col = len(countriesCO2DF.columns)
 
# printing
print(f'Dimension of the Dataframe is: {(row,col)}')
print(f'Number of Rows are: {row}')
print(f'Number of Columns are: {col}')
# Out:
# Dimension of the Dataframe is: (190, 2)
# Number of Rows are: 190
# Number of Columns are: 2

# %%
countriesCO2DF.show(190, False)
# Out:
# +--------------------------------+----------------+
# |cn                              |count(c02_level)|
# +--------------------------------+----------------+
# |United States                   |17050           |
# |China                           |3616            |
# |Republic of Korea               |2942            |
# |Japan                           |2935            |
# |Germany                         |1966            |
# |United Kingdom                  |1660            |
# |Canada                          |1564            |
# |Russia                          |1508            |
# |France                          |1353            |
# |Brazil                          |856             |
# |Australia                       |769             |
# |Sweden                          |724             |
# |Italy                           |713             |
# |Poland                          |664             |
# |Netherlands                     |646             |
# |Spain                           |586             |
# |Taiwan                          |542             |
# |India                           |446             |
# |                                |427             |
# |Norway                          |399             |
# |Ukraine                         |373             |
# |Austria                         |360             |
# |Czech Republic                  |359             |
# |Hong Kong                       |350             |
# |Switzerland                     |343             |
# |Bulgaria                        |307             |
# |Romania                         |306             |
# |Mexico                          |297             |
# |Denmark                         |288             |
# |Singapore                       |285             |
# |Thailand                        |228             |
# |Indonesia                       |226             |
# |Argentina                       |223             |
# |Hungary                         |210             |
# |Malaysia                        |187             |
# |Turkey                          |171             |
# |Israel                          |169             |
# |Finland                         |157             |
# |Belgium                         |153             |
# |Philippines                     |145             |
# |South Africa                    |133             |
# |New Zealand                     |120             |
# |Ireland                         |118             |
# |Colombia                        |115             |
# |Portugal                        |102             |
# |Greece                          |98              |
# |Iran                            |93              |
# |Chile                           |86              |
# |Slovak Republic                 |81              |
# |Republic of Lithuania           |78              |
# |Egypt                           |70              |
# |Slovenia                        |68              |
# |Latvia                          |68              |
# |Puerto Rico                     |66              |
# |Croatia                         |62              |
# |Pakistan                        |58              |
# |Vietnam                         |57              |
# |Ecuador                         |55              |
# |Serbia                          |55              |
# |Venezuela                       |50              |
# |Kazakhstan                      |42              |
# |Bangladesh                      |40              |
# |Kuwait                          |39              |
# |Estonia                         |38              |
# |Peru                            |38              |
# |Bolivia                         |35              |
# |Uruguay                         |32              |
# |Bosnia and Herzegovina          |30              |
# |Belarus                         |29              |
# |Panama                          |29              |
# |Costa Rica                      |29              |
# |Saudi Arabia                    |28              |
# |United Arab Emirates            |27              |
# |Georgia                         |25              |
# |Kenya                           |24              |
# |Luxembourg                      |23              |
# |Republic of Moldova             |22              |
# |Cyprus                          |21              |
# |Macedonia                       |20              |
# |Qatar                           |20              |
# |Morocco                         |19              |
# |Sri Lanka                       |19              |
# |Iceland                         |19              |
# |El Salvador                     |19              |
# |Nigeria                         |16              |
# |Tanzania                        |15              |
# |Bermuda                         |15              |
# |Hashemite Kingdom of Jordan     |14              |
# |Barbados                        |14              |
# |Malta                           |14              |
# |Antigua and Barbuda             |14              |
# |Kyrgyzstan                      |14              |
# |Lebanon                         |14              |
# |Bahrain                         |13              |
# |Azerbaijan                      |13              |
# |Guam                            |13              |
# |U.S. Virgin Islands             |12              |
# |Nicaragua                       |12              |
# |Guatemala                       |12              |
# |Honduras                        |12              |
# |Cambodia                        |11              |
# |Jersey                          |10              |
# |Nepal                           |10              |
# |Macao                           |9               |
# |Monaco                          |9               |
# |Uzbekistan                      |9               |
# |Mongolia                        |9               |
# |Namibia                         |9               |
# |Palestine                       |8               |
# |Cameroon                        |8               |
# |Angola                          |8               |
# |Mauritius                       |8               |
# |Armenia                         |8               |
# |Ghana                           |8               |
# |Zimbabwe                        |8               |
# |Saint Kitts and Nevis           |7               |
# |Trinidad and Tobago             |7               |
# |Jamaica                         |7               |
# |Cayman Islands                  |7               |
# |Sudan                           |7               |
# |Tunisia                         |7               |
# |Algeria                         |7               |
# |Dominica                        |6               |
# |Albania                         |6               |
# |Curaçao                         |6               |
# |Uganda                          |6               |
# |Paraguay                        |6               |
# |Afghanistan                     |6               |
# |Brunei                          |6               |
# |Libya                           |6               |
# |Bahamas                         |5               |
# |Cuba                            |5               |
# |French Polynesia                |5               |
# |Oman                            |5               |
# |Dominican Republic              |5               |
# |Åland                           |5               |
# |Mozambique                      |5               |
# |Botswana                        |5               |
# |Haiti                           |5               |
# |Madagascar                      |5               |
# |Senegal                         |5               |
# |Belize                          |5               |
# |Burkina Faso                    |5               |
# |Guadeloupe                      |4               |
# |Liechtenstein                   |4               |
# |Kosovo                          |4               |
# |Swaziland                       |4               |
# |New Caledonia                   |4               |
# |Congo                           |4               |
# |Mauritania                      |4               |
# |Laos                            |3               |
# |Montenegro                      |3               |
# |Syria                           |3               |
# |Papua New Guinea                |3               |
# |Faroe Islands                   |3               |
# |Mali                            |3               |
# |Maldives                        |3               |
# |Togo                            |2               |
# |Lesotho                         |2               |
# |Vanuatu                         |2               |
# |Bhutan                          |2               |
# |Aruba                           |2               |
# |Yemen                           |2               |
# |San Marino                      |2               |
# |Rwanda                          |2               |
# |Saint Vincent and the Grenadines|2               |
# |Saint Lucia                     |2               |
# |Fiji                            |2               |
# |Isle of Man                     |2               |
# |Sint Maarten                    |2               |
# |British Virgin Islands          |2               |
# |Iraq                            |2               |
# |Gambia                          |2               |
# |Northern Mariana Islands        |2               |
# |Zambia                          |2               |
# |Ivory Coast                     |1               |
# |Marshall Islands                |1               |
# |Andorra                         |1               |
# |British Indian Ocean Territory  |1               |
# |Réunion                         |1               |
# |Tajikistan                      |1               |
# |Gibraltar                       |1               |
# |Gabon                           |1               |
# |Falkland Islands                |1               |
# |Federated States of Micronesia  |1               |
# |Turkmenistan                    |1               |
# |Guernsey                        |1               |
# |Solomon Islands                 |1               |
# |East Timor                      |1               |
# |Liberia                         |1               |
# +--------------------------------+----------------+

# %% [markdown]
# ## 5.Select all countries' devices with high-levels of C02 and group by cca3 and order by device_ids

# %% [markdown]
# #### Hint: For high CO2 level, the LCD status will be RED

# %%
LCD = spark.sql("SELECT cca3, COUNT(device_id) FROM iot WHERE lcd LIKE '%red%' GROUP BY cca3 ORDER BY COUNT(device_id) DESC")

# %%
# extracting number of rows from the Dataframe
row = LCD.count()
   
# extracting number of columns from the Dataframe
col = len(LCD.columns)
 
# printing
print(f'Dimension of the Dataframe is: {(row,col)}')
print(f'Number of Rows are: {row}')
print(f'Number of Columns are: {col}')
# Out:
# Dimension of the Dataframe is: (186, 2)
# Number of Rows are: 186
# Number of Columns are: 2

# %%
LCD.show(186, False)
# Out:
# +----+----------------+
# |cca3|count(device_id)|
# +----+----------------+
# |USA |17489           |
# |CHN |3616            |
# |KOR |2942            |
# |JPN |2935            |
# |DEU |1966            |
# |GBR |1660            |
# |CAN |1564            |
# |RUS |1508            |
# |FRA |1353            |
# |BRA |856             |
# |AUS |769             |
# |SWE |724             |
# |ITA |713             |
# |POL |664             |
# |NLD |646             |
# |ESP |586             |
# |TWN |542             |
# |IND |446             |
# |NOR |399             |
# |UKR |373             |
# |AUT |360             |
# |CZE |359             |
# |HKG |350             |
# |CHE |343             |
# |BGR |307             |
# |ROU |306             |
# |MEX |297             |
# |DNK |288             |
# |SGP |285             |
# |THA |228             |
# |IDN |226             |
# |ARG |223             |
# |HUN |210             |
# |MYS |187             |
# |TUR |171             |
# |ISR |169             |
# |FIN |157             |
# |BEL |153             |
# |PHL |145             |
# |ZAF |133             |
# |NZL |120             |
# |IRL |118             |
# |COL |115             |
# |PRT |102             |
# |GRC |98              |
# |IRN |93              |
# |CHL |86              |
# |SVK |81              |
# |LTU |78              |
# |EGY |70              |
# |LVA |68              |
# |SVN |68              |
# |PRI |66              |
# |HRV |62              |
# |PAK |58              |
# |VNM |57              |
# |SRB |55              |
# |ECU |55              |
# |VEN |50              |
# |KAZ |42              |
# |BGD |40              |
# |KWT |39              |
# |EST |38              |
# |PER |38              |
# |BOL |35              |
# |URY |32              |
# |BIH |30              |
# |PAN |29              |
# |CRI |29              |
# |BLR |29              |
# |SAU |28              |
# |ARE |27              |
# |GEO |25              |
# |KEN |24              |
# |LUX |23              |
# |MDA |22              |
# |CYP |21              |
# |QAT |20              |
# |MKD |20              |
# |MAR |19              |
# |ISL |19              |
# |LKA |19              |
# |SLV |19              |
# |NGA |16              |
# |BMU |15              |
# |TZA |15              |
# |ATG |14              |
# |LBN |14              |
# |JOR |14              |
# |MLT |14              |
# |BRB |14              |
# |KGZ |14              |
# |AZE |13              |
# |BHR |13              |
# |GUM |13              |
# |VIR |12              |
# |HND |12              |
# |GTM |12              |
# |NIC |12              |
# |KHM |11              |
# |JEY |10              |
# |NPL |10              |
# |UZB |9               |
# |MNG |9               |
# |MCO |9               |
# |NAM |9               |
# |MAC |9               |
# |GHA |8               |
# |CMR |8               |
# |MUS |8               |
# |AGO |8               |
# |ZWE |8               |
# |PSE |8               |
# |ARM |8               |
# |SDN |7               |
# |TTO |7               |
# |CYM |7               |
# |DZA |7               |
# |KNA |7               |
# |TUN |7               |
# |JAM |7               |
# |PRY |6               |
# |UGA |6               |
# |DMA |6               |
# |ALB |6               |
# |LBY |6               |
# |AFG |6               |
# |BRN |6               |
# |MOZ |5               |
# |BHS |5               |
# |CUB |5               |
# |BWA |5               |
# |MDG |5               |
# |SEN |5               |
# |BFA |5               |
# |OMN |5               |
# |PYF |5               |
# |DOM |5               |
# |HTI |5               |
# |ALA |5               |
# |BLZ |5               |
# |MRT |4               |
# |COD |4               |
# |NCL |4               |
# |GLP |4               |
# |LIE |4               |
# |SWZ |4               |
# |LAO |3               |
# |MLI |3               |
# |FRO |3               |
# |SYR |3               |
# |PNG |3               |
# |MDV |3               |
# |MNE |3               |
# |VCT |2               |
# |GMB |2               |
# |VUT |2               |
# |RWA |2               |
# |ABW |2               |
# |LSO |2               |
# |BTN |2               |
# |ZMB |2               |
# |LCA |2               |
# |VGB |2               |
# |YEM |2               |
# |SMR |2               |
# |MNP |2               |
# |IRQ |2               |
# |FJI |2               |
# |IMN |2               |
# |TGO |2               |
# |AND |1               |
# |CIV |1               |
# |MHL |1               |
# |FSM |1               |
# |GIB |1               |
# |IOT |1               |
# |GAB |1               |
# |REU |1               |
# |FLK |1               |
# |GGY |1               |
# |TJK |1               |
# |TKM |1               |
# |TLS |1               |
# |SLB |1               |
# |LBR |1               |
# +----+----------------+

# %% [markdown]
# ## 6.Find out all devices in countries whose batteries need replacements.

# %%
iotDF.select("battery_level").distinct().show()
# Out:
# +-------------+
# |battery_level|
# +-------------+
# |            0|
# |            7|
# |            6|
# |            9|
# |            5|
# |            1|
# |            3|
# |            8|
# |            2|
# |            4|
# +-------------+

# %%
battery_replacement = spark.sql("SELECT cn, device_name, device_id FROM iot WHERE battery_level = 0")

# %%
# extracting number of rows from the Dataframe
row = battery_replacement.count()
   
# extracting number of columns from the Dataframe
col = len(battery_replacement.columns)
 
# printing
print(f'Dimension of the Dataframe is: {(row,col)}')
print(f'Number of Rows are: {row}')
print(f'Number of Columns are: {col}')
# Out:
# Dimension of the Dataframe is: (19851, 3)
# Number of Rows are: 19851
# Number of Columns are: 3

# %%
battery_replacement.show(19851, False)
# Out:
# +------------------------------+----------------------------+---------+
# |cn                            |device_name                 |device_id|
# +------------------------------+----------------------------+---------+
# |Japan                         |sensor-pad-8xUD6pzsQI       |8        |
# |United States                 |sensor-pad-12Y2kIm0o        |12       |
# |United States                 |meter-gauge-17zb8Fghhl      |17       |
# |Germany                       |sensor-pad-448DeWGL         |44       |
# |Canada                        |sensor-pad-80TY4dWSMH       |80       |
# |Republic of Korea             |sensor-pad-92vxuq7e         |92       |
# |United States                 |sensor-pad-98mJQAfJpfW      |98       |
# |Japan                         |meter-gauge-1075KSUDRjPa    |107      |
# |Australia                     |device-mac-111WYtjxe1b      |111      |
# |United States                 |sensor-pad-11663yUf         |116      |
# |China                         |device-mac-117mccYyRo       |117      |
# |United States                 |device-mac-123zvY7uWFB      |123      |
# |United States                 |meter-gauge-131LbuCgFDFfz   |131      |
# |United States                 |sensor-pad-1344UGR6ipMd     |134      |
# |Germany                       |sensor-pad-140tq1s6t        |140      |
# |China                         |meter-gauge-151GjiQlha5Gq   |151      |
# |China                         |sensor-pad-156nfjyi4czw     |156      |
# |United States                 |meter-gauge-167c49F2rsfd    |167      |
# |United States                 |meter-gauge-1794X82qoL      |179      |
# |South Africa                  |sensor-pad-180lj1Gh9L6cP    |180      |
# |United States                 |therm-stick-185hLXCLeDto    |185      |
# |United States                 |device-mac-195EFN3e8fAcg    |195      |
# |France                        |sensor-pad-196gGPVR0        |196      |
# |United States                 |meter-gauge-2092AWTuovHc    |209      |
# |Germany                       |sensor-pad-210QLYyxpL       |210      |
# |United States                 |meter-gauge-217TwSfC        |217      |
# |Finland                       |sensor-pad-218Zt58LJIgM     |218      |
# |Poland                        |device-mac-219BL7ifYGb0     |219      |
# |Argentina                     |meter-gauge-2273pen9hQb     |227      |
# |                              |meter-gauge-241un29KmR      |241      |
# |Monaco                        |sensor-pad-244p6oYcsl79k    |244      |
# |United States                 |meter-gauge-253jo81wYOW     |253      |
# |Costa Rica                    |sensor-pad-2685AydUae       |268      |
# |United States                 |meter-gauge-281UfiZUxpl     |281      |
# |China                         |sensor-pad-2824teEA9        |282      |
# |United States                 |meter-gauge-283wT3UOgJZ     |283      |
# |Taiwan                        |sensor-pad-312SABXiei1rj    |312      |
# |United States                 |meter-gauge-331j8YASFgep    |331      |
# |United States                 |meter-gauge-337kMdpfwjEE    |337      |
# |France                        |device-mac-345FVTWd         |345      |
# |United States                 |sensor-pad-354ztT0hX9Ik     |354      |
# |Canada                        |meter-gauge-3738wCnQ        |373      |
# |Poland                        |sensor-pad-378SgqAQkyHZG    |378      |
# |United States                 |device-mac-387PnF8U         |387      |
# |South Africa                  |sensor-pad-390N0EKRKr       |390      |
# |Japan                         |device-mac-399Mdg0tyw62b    |399      |
# |Canada                        |meter-gauge-413UMKlGuP      |413      |
# |Republic of Korea             |sensor-pad-414PjKOFZF9IH    |414      |
# |Germany                       |sensor-pad-41619hPO1Yvi     |416      |
# |United Kingdom                |sensor-pad-436W0D6YgirKM    |436      |
# |Australia                     |meter-gauge-439SYSeBTbouP   |439      |
# |United States                 |sensor-pad-444HxOHj         |444      |
# |South Africa                  |sensor-pad-446Tl3tiM3kPO    |446      |
# |Latvia                        |meter-gauge-449ezuX2HqqS    |449      |
# |China                         |sensor-pad-454itpmrl        |454      |
# |United States                 |meter-gauge-503G7rWBFZgz    |503      |
# |United States                 |device-mac-549PnwJns        |549      |
# |India                         |sensor-pad-5705GgE3         |570      |
# |United States                 |meter-gauge-5872Mo1cAva     |587      |
# |United States                 |device-mac-591pAg6HCj       |591      |
# |United States                 |sensor-pad-596alRtKhKSbm    |596      |
# |United States                 |meter-gauge-599W5vB4QW6wq   |599      |
# |United States                 |therm-stick-6250IGwKXU      |625      |
# |Croatia                       |sensor-pad-632fA68rXrtt     |632      |
# |Republic of Korea             |therm-stick-635D3Hu0        |635      |
# |Republic of Korea             |sensor-pad-640i6wFra0h      |640      |
# |China                         |meter-gauge-641bkXXrwCA     |641      |
# |China                         |sensor-pad-6443kUqEEJ       |644      |
# |Singapore                     |meter-gauge-649vuxBXe       |649      |
# |Republic of Korea             |sensor-pad-654bfPYc         |654      |
# |China                         |meter-gauge-6714z0XeZpc7    |671      |
# |Hong Kong                     |sensor-pad-674O4bW3         |674      |
# |China                         |device-mac-681TPaHg         |681      |
# |Norway                        |sensor-pad-6865SJHBERGGC    |686      |
# |India                         |sensor-pad-688Vd2bX         |688      |
# |China                         |sensor-pad-692m2V38         |692      |
# |Republic of Korea             |device-mac-705Fd2hkANOW     |705      |
# |United States                 |sensor-pad-7060nq1gMNd5     |706      |
# |United States                 |sensor-pad-724MAEisU        |724      |
# |Latvia                        |device-mac-735E1rXvbzuvS    |735      |
# |United States                 |meter-gauge-739TLykPoAo     |739      |
# |Italy                         |sensor-pad-742TAM0gmzUj     |742      |
# |Republic of Korea             |meter-gauge-749URFaH3Sjy    |749      |
# |United Kingdom                |meter-gauge-809Vj09gny      |809      |
# |Australia                     |meter-gauge-817eAeG5T       |817      |
# |Switzerland                   |sensor-pad-822rFy3YzLm8     |822      |
# |United States                 |meter-gauge-839Hz5FZ        |839      |
# |                              |meter-gauge-857Qg2xEOp      |857      |
# |Israel                        |device-mac-867ZhqYc         |867      |
# |United States                 |meter-gauge-8698KzyzfNZ     |869      |
# |United States                 |sensor-pad-88435sF8u        |884      |
# |Japan                         |sensor-pad-888zWjj4H        |888      |
# |Republic of Korea             |sensor-pad-896bj7Gzy        |896      |
# |United States                 |sensor-pad-902e7sjet        |902      |
# |United Kingdom                |sensor-pad-904VPVxQ1F       |904      |
# |Republic of Korea             |device-mac-915u1MkX         |915      |
# |Spain                         |sensor-pad-9306PmoNN9DH     |930      |
# |Australia                     |device-mac-939ng1nz8kkH     |939      |
# |Argentina                     |meter-gauge-943BT5wQ057     |943      |
# |Austria                       |sensor-pad-974x9dkX1        |974      |
# |Canada                        |device-mac-975Zcm9meJ       |975      |
# |United States                 |sensor-pad-982gd9s7YWt      |982      |
# |Republic of Korea             |device-mac-987WfGIZFLRAb    |987      |
# |United States                 |meter-gauge-1001csGfYF10l   |1001     |
# |Japan                         |device-mac-1005rLsPu        |1005     |
# |China                         |sensor-pad-1006hQLKr9w1S    |1006     |
# |United States                 |sensor-pad-1008oaUOY        |1008     |
# |United States                 |sensor-pad-1014RlcnBJZVqq   |1014     |
# |Belgium                       |device-mac-1023ZwihXHN1sq   |1023     |
# |China                         |sensor-pad-1050bomFdJ       |1050     |
# |United States                 |sensor-pad-1054chHSf        |1054     |
# |                              |device-mac-1059vEKl5B3Lv    |1059     |
# |United States                 |meter-gauge-1087i2U9Vl7RsC  |1087     |
# |Sweden                        |device-mac-1101vs9zMSRVl    |1101     |
# |United States                 |therm-stick-11155wG1T5OD1L  |1115     |
# |Denmark                       |meter-gauge-1123GukkyWeDi   |1123     |
# |Canada                        |device-mac-1131Cc6fw1JO9    |1131     |
# |Bulgaria                      |meter-gauge-11390JBFUpa9    |1139     |
# |                              |sensor-pad-1158ScW7tifH     |1158     |
# |United States                 |sensor-pad-1172WtmKMP5G     |1172     |
# |Costa Rica                    |sensor-pad-1174KPp5m6a      |1174     |
# |United States                 |therm-stick-1195ag4NksU     |1195     |
# |China                         |sensor-pad-1196H3HGEoHTcH   |1196     |
# |United States                 |sensor-pad-1206QfW6wc4      |1206     |
# |Republic of Korea             |meter-gauge-12236MjsU8znZX  |1223     |
# |United States                 |meter-gauge-1237aMCB2       |1237     |
# |Germany                       |meter-gauge-12414MAYDjD3Lo  |1241     |
# |China                         |therm-stick-1265i5Glnapy    |1265     |
# |Taiwan                        |sensor-pad-1272913u5u       |1272     |
# |Serbia                        |sensor-pad-1274QEUqJ        |1274     |
# |France                        |meter-gauge-1279NyKDj9wqsO  |1279     |
# |Japan                         |sensor-pad-1284dEz1xfYv     |1284     |
# |United States                 |sensor-pad-1288FOMuzgke     |1288     |
# |United States                 |sensor-pad-1310kVyfnUxJg    |1310     |
# |Republic of Korea             |device-mac-1311C8pWK        |1311     |
# |United Kingdom                |meter-gauge-1313lOl6UBmpUK  |1313     |
# |United States                 |therm-stick-1315UQHoux1ttE  |1315     |
# |Republic of Korea             |sensor-pad-1324d8IC8        |1324     |
# |China                         |meter-gauge-1327ZYIFgSq     |1327     |
# |United States                 |meter-gauge-1343JZJoE8x4jZ  |1343     |
# |Malaysia                      |sensor-pad-1354F3bPTLn4R    |1354     |
# |France                        |meter-gauge-1361CmBsNxa0V   |1361     |
# |Canada                        |sensor-pad-1382cX817SRb     |1382     |
# |United States                 |sensor-pad-1392DgmDL        |1392     |
# |France                        |meter-gauge-1393kteWDBbGs   |1393     |
# |United States                 |sensor-pad-1394ACTtTe0      |1394     |
# |Republic of Korea             |sensor-pad-1396Lfd77o       |1396     |
# |Republic of Korea             |sensor-pad-1400AcKcVfg      |1400     |
# |China                         |sensor-pad-1410awngNXi      |1410     |
# |Russia                        |meter-gauge-1421UdywAu      |1421     |
# |India                         |sensor-pad-1444eAiOyw       |1444     |
# |Germany                       |therm-stick-14453TR6Wf7Z    |1445     |
# |United States                 |sensor-pad-1472Hik0Z4       |1472     |
# |Japan                         |sensor-pad-1478PJZ59edi     |1478     |
# |United Kingdom                |sensor-pad-1482QIsQTsh      |1482     |
# |Spain                         |sensor-pad-1488p3ZSgnJw     |1488     |
# |Indonesia                     |sensor-pad-1496eG1VDjdb     |1496     |
# |United States                 |sensor-pad-1512lZNu9pgrM    |1512     |
# |Hong Kong                     |sensor-pad-15140KLMVibVC    |1514     |
# |India                         |sensor-pad-15168qR3IS       |1516     |
# |                              |device-mac-1521KUBAw8       |1521     |
# |Spain                         |device-mac-1527e7PvKqLPAD   |1527     |
# |United States                 |meter-gauge-1543rLnw5       |1543     |
# |Austria                       |sensor-pad-1550pUKWA0hH     |1550     |
# |China                         |device-mac-15630w7vEkQx0j   |1563     |
# |Taiwan                        |sensor-pad-1580ZByxUcdX3n   |1580     |
# |Czech Republic                |meter-gauge-1597bDboj3HzK   |1597     |
# |United States                 |sensor-pad-1600QWjxn        |1600     |
# |China                         |sensor-pad-1616xehLk3s      |1616     |
# |China                         |device-mac-1623LMvaPx3B     |1623     |
# |Vietnam                       |therm-stick-1655qdGfRJ      |1655     |
# |Thailand                      |sensor-pad-16684ioWw4L      |1668     |
# |Malaysia                      |sensor-pad-1670GqWwHjoS0    |1670     |
# |United Kingdom                |device-mac-1683Yh3Cgj       |1683     |
# |United States                 |meter-gauge-1717KI9ouxQ     |1717     |
# |Ecuador                       |sensor-pad-1730a9ofSxQj7z   |1730     |
# |Mexico                        |sensor-pad-1744jIK7T        |1744     |
# |U.S. Virgin Islands           |sensor-pad-1750QSFXxIfF     |1750     |
# |Ukraine                       |sensor-pad-1776cXdikljHkX   |1776     |
# |United States                 |sensor-pad-17827qAY55Z8     |1782     |
# |United States                 |meter-gauge-1783YxrQENi     |1783     |
# |Republic of Korea             |sensor-pad-17849iPVBQmt     |1784     |
# |United States                 |sensor-pad-1816GRsfJ        |1816     |
# |United States                 |sensor-pad-1842a5T9qVKQ     |1842     |
# |Canada                        |sensor-pad-18509LDPxkdG     |1850     |
# |United States                 |sensor-pad-18649Rrnn63DN    |1864     |
# |United States                 |device-mac-1869e6QERhSTm    |1869     |
# |Canada                        |sensor-pad-1870InYZo        |1870     |
# |Russia                        |sensor-pad-1882A7vOswh      |1882     |
# |Republic of Korea             |therm-stick-19153hpGMhnd    |1915     |
# |United States                 |device-mac-1917iwkrkHCR     |1917     |
# |United States                 |sensor-pad-1932Gu46N        |1932     |
# |Kuwait                        |meter-gauge-1937c2sZTe5FVT  |1937     |
# |United Kingdom                |device-mac-1959mBzGY        |1959     |
# |United Kingdom                |meter-gauge-1961pMrkCI8xa   |1961     |
# |United States                 |sensor-pad-1972YQVMKz       |1972     |
# |Germany                       |sensor-pad-1980aI3Hb        |1980     |
# |France                        |sensor-pad-1982y7Pgb03lVe   |1982     |
# |United States                 |sensor-pad-1986utpP3        |1986     |
# |United Kingdom                |device-mac-1995BNBDWcv      |1995     |
# |France                        |sensor-pad-20089mfuhBZ      |2008     |
# |Brazil                        |device-mac-20132qeIm4LgW    |2013     |
# |Sweden                        |therm-stick-2035CHlpLFC3k   |2035     |
# |United States                 |sensor-pad-2040kKvwnJ       |2040     |
# |Brazil                        |device-mac-2055vsES4IP      |2055     |
# |Germany                       |sensor-pad-2058zcO5Ax       |2058     |
# |Israel                        |device-mac-2067eBCLhY       |2067     |
# |China                         |therm-stick-2075LK0sMDF9H   |2075     |
# |Japan                         |meter-gauge-2077pHCl4       |2077     |
# |China                         |sensor-pad-2080TdtnAmW4l    |2080     |
# |Russia                        |meter-gauge-2083ZGQxz2JLsO  |2083     |
# |United States                 |sensor-pad-2084pWfy0vXI     |2084     |
# |United States                 |sensor-pad-2086uGl2tF       |2086     |
# |Netherlands                   |sensor-pad-2098BwN6Mx       |2098     |
# |Sudan                         |sensor-pad-2100crUVb        |2100     |
# |United States                 |sensor-pad-2106OYbkX        |2106     |
# |United States                 |meter-gauge-2107IZrmULkWzL  |2107     |
# |Azerbaijan                    |sensor-pad-2112BZ9yhrOsYE   |2112     |
# |Russia                        |sensor-pad-2120fCgdE9       |2120     |
# |Sweden                        |meter-gauge-2159Q8L2eGOM    |2159     |
# |Russia                        |meter-gauge-2161xZklt4hegd  |2161     |
# |United States                 |sensor-pad-2162hcr5a        |2162     |
# |Republic of Korea             |meter-gauge-2179ONx6T2      |2179     |
# |United States                 |device-mac-2187Ps1YSL9B     |2187     |
# |China                         |device-mac-2193i1lReo       |2193     |
# |Romania                       |sensor-pad-2194JCZHiKSHt7   |2194     |
# |United States                 |sensor-pad-2204vTY23        |2204     |
# |United Kingdom                |sensor-pad-2212Rhfnewb      |2212     |
# |United States                 |therm-stick-2215I5TyqQljg   |2215     |
# |Japan                         |sensor-pad-2222NPdDT4i      |2222     |
# |Russia                        |sensor-pad-22787uetohaml    |2278     |
# |Philippines                   |meter-gauge-2293R9ESx       |2293     |
# |Canada                        |sensor-pad-2294quHUbL       |2294     |
# |United States                 |device-mac-2295VPTFAN4tDN   |2295     |
# |Germany                       |sensor-pad-2300je5Yyy5eY    |2300     |
# |Republic of Korea             |device-mac-2313vh9DWbv      |2313     |
# |Austria                       |sensor-pad-2326HfjS7EG      |2326     |
# |Germany                       |meter-gauge-2327sazZ4GSAXr  |2327     |
# |Brazil                        |device-mac-236199wi5C       |2361     |
# |United States                 |sensor-pad-2366QPHkmP       |2366     |
# |China                         |device-mac-2397cgGaj        |2397     |
# |Germany                       |sensor-pad-2400P2ftZ7       |2400     |
# |Japan                         |device-mac-2433jie5IiZt     |2433     |
# |Switzerland                   |meter-gauge-2437wLSsctz     |2437     |
# |China                         |sensor-pad-2442p9MJkZ8AwB   |2442     |
# |Japan                         |sensor-pad-2444lzX3oOzUMU   |2444     |
# |United States                 |sensor-pad-2454bFGQEhZ7wP   |2454     |
# |United States                 |sensor-pad-2478C6UKB        |2478     |
# |New Zealand                   |sensor-pad-2482G6P02285     |2482     |
# |Sweden                        |meter-gauge-2483RdjvWeULt   |2483     |
# |United States                 |meter-gauge-2519p4WOzLWKBI  |2519     |
# |Germany                       |sensor-pad-2530zIaaMYAzWa   |2530     |
# |France                        |meter-gauge-2531QjnmsQbF    |2531     |
# |United States                 |sensor-pad-2532anKjEu       |2532     |
# |                              |sensor-pad-2534IRNaesT7     |2534     |
# |United States                 |sensor-pad-2544w0d0tjM      |2544     |
# |United States                 |meter-gauge-2557F5lXcXNW    |2557     |
# |Hong Kong                     |sensor-pad-25762QK2cfUsO    |2576     |
# |                              |sensor-pad-2592Ae6yTC6HzD   |2592     |
# |China                         |device-mac-2601x8yrsLo      |2601     |
# |Canada                        |sensor-pad-2608Qfd07sj9w    |2608     |
# |Russia                        |sensor-pad-2650cRiG7Zd      |2650     |
# |Estonia                       |device-mac-2667gPM2K6yvx    |2667     |
# |Italy                         |meter-gauge-2677y5wUEy9uS   |2677     |
# |United States                 |sensor-pad-2686Drc6oXAg     |2686     |
# |United States                 |sensor-pad-2692dO7kTjbf     |2692     |
# |United States                 |sensor-pad-2696GFJ1d6S      |2696     |
# |United Kingdom                |meter-gauge-27019npvDEAz    |2701     |
# |United States                 |meter-gauge-2723Jj4cnBx     |2723     |
# |United States                 |sensor-pad-2724NhxvYbhwn    |2724     |
# |Canada                        |device-mac-2733AzLo8gS      |2733     |
# |Australia                     |sensor-pad-2742HWanFS9eu    |2742     |
# |China                         |sensor-pad-2752qGsMI4r      |2752     |
# |Russia                        |sensor-pad-2756YMEXXu5xF    |2756     |
# |China                         |device-mac-2757kbU7rvHU     |2757     |
# |United States                 |sensor-pad-27581xrYT        |2758     |
# |United Kingdom                |meter-gauge-2759kmUYG       |2759     |
# |Japan                         |device-mac-2787VysU1wKCX    |2787     |
# |Australia                     |sensor-pad-2788eqgKbqJrA    |2788     |
# |Japan                         |meter-gauge-2791gEJJfQbZcl  |2791     |
# |Russia                        |device-mac-2793Zs6y7GtnL1   |2793     |
# |United States                 |device-mac-28114XHj0        |2811     |
# |United States                 |sensor-pad-2816tiDkETz7     |2816     |
# |Argentina                     |device-mac-2817fhJJFm86Z    |2817     |
# |Japan                         |meter-gauge-2819CrlYWonS    |2819     |
# |Mexico                        |meter-gauge-2839yQsLRQ      |2839     |
# |Japan                         |sensor-pad-2840hrRXgV       |2840     |
# |Canada                        |sensor-pad-2842V6KoksHIEt   |2842     |
# |China                         |meter-gauge-2861WvlOrgH60   |2861     |
# |China                         |meter-gauge-2867oXZUfCcKfK  |2867     |
# |Spain                         |meter-gauge-29035v7SdGv0    |2903     |
# |Italy                         |meter-gauge-2909HfY7MCe     |2909     |
# |China                         |sensor-pad-2914IimEdK       |2914     |
# |United States                 |device-mac-2919bA12yn       |2919     |
# |Costa Rica                    |meter-gauge-2933ofMbFsU     |2933     |
# |United States                 |sensor-pad-2936hC99l        |2936     |
# |United Kingdom                |device-mac-2937e2bkZbSUio   |2937     |
# |United States                 |meter-gauge-2959WUgRtAYm8   |2959     |
# |United Kingdom                |sensor-pad-2962pO14fJL      |2962     |
# |United States                 |therm-stick-2975r5C73pd     |2975     |
# |United States                 |device-mac-2985ixuPDyu      |2985     |
# |France                        |sensor-pad-2986aBNrPlY      |2986     |
# |Russia                        |sensor-pad-3004ZyJfruzy0G   |3004     |
# |Republic of Korea             |device-mac-3009dMsfuTw      |3009     |
# |China                         |sensor-pad-3012bHJqhZz      |3012     |
# |United States                 |meter-gauge-3013ec6lHl7     |3013     |
# |United States                 |device-mac-3021Artcqkxx3    |3021     |
# |United States                 |sensor-pad-3030Ecl4QXCNF    |3030     |
# |Mexico                        |meter-gauge-3031rdcUvyXM    |3031     |
# |United States                 |therm-stick-3035ypr08BhB    |3035     |
# |Hong Kong                     |sensor-pad-3044a8ZxKxkDym   |3044     |
# |United States                 |sensor-pad-3052GbZzm        |3052     |
# |Russia                        |device-mac-3057TWILoHH      |3057     |
# |Hong Kong                     |meter-gauge-3059JSFDci7bA   |3059     |
# |United Kingdom                |meter-gauge-30674nE47oc     |3067     |
# |United States                 |sensor-pad-30825PIZgIHUAL   |3082     |
# |Japan                         |device-mac-3087wbWUm        |3087     |
# |Japan                         |sensor-pad-3110l1u54        |3110     |
# |Japan                         |sensor-pad-3112uGTtzG3N     |3112     |
# |United States                 |sensor-pad-3148esnYRDBDwO   |3148     |
# |Colombia                      |device-mac-3153QaGHWVG      |3153     |
# |United Kingdom                |meter-gauge-3163ug1mUH0qJO  |3163     |
# |Russia                        |meter-gauge-3169YCvkJD      |3169     |
# |United Kingdom                |therm-stick-3175p6I4zu      |3175     |
# |United States                 |sensor-pad-3202mymqr        |3202     |
# |Mexico                        |meter-gauge-3203mCqaUxf6F   |3203     |
# |Republic of Korea             |sensor-pad-3210MxpRN        |3210     |
# |Republic of Korea             |meter-gauge-3221S6PZRTKvE   |3221     |
# |United States                 |meter-gauge-3223sS0ny       |3223     |
# |United States                 |sensor-pad-3230wTWou        |3230     |
# |United States                 |device-mac-3231DROMiM       |3231     |
# |Canada                        |meter-gauge-32591PQbOvAt0   |3259     |
# |Japan                         |meter-gauge-3277J1fTOvk     |3277     |
# |Japan                         |meter-gauge-3287g3rfzl6     |3287     |
# |Kenya                         |sensor-pad-3292HamgYiM      |3292     |
# |United States                 |meter-gauge-3301RP2RA       |3301     |
# |France                        |sensor-pad-33141XMKEX       |3314     |
# |Germany                       |sensor-pad-33244nVzLAK      |3324     |
# |Yemen                         |sensor-pad-3342XBOY9qC      |3342     |
# |United States                 |device-mac-3381NDPK1MdNn3   |3381     |
# |United States                 |therm-stick-3385288VL81W    |3385     |
# |Bulgaria                      |device-mac-3417Y8HHoC       |3417     |
# |Ukraine                       |sensor-pad-3422hfb6MmXOUK   |3422     |
# |United States                 |sensor-pad-3442mZ44ezApnl   |3442     |
# |United States                 |sensor-pad-3456LtjsY8hEGK   |3456     |
# |United States                 |sensor-pad-34661gcpA        |3466     |
# |United States                 |meter-gauge-3469jRQ4fq1N    |3469     |
# |Brazil                        |sensor-pad-3474n3UWT        |3474     |
# |India                         |sensor-pad-3498bYRaGbeW     |3498     |
# |France                        |meter-gauge-3499dseAexm     |3499     |
# |United States                 |sensor-pad-3534fJN2L3       |3534     |
# |Republic of Korea             |therm-stick-3535HXcLo       |3535     |
# |China                         |meter-gauge-3553GJRpy       |3553     |
# |Japan                         |sensor-pad-3560rBAgR14l     |3560     |
# |Brazil                        |sensor-pad-3572sDCvObI      |3572     |
# |United States                 |sensor-pad-3576vKlQUYa      |3576     |
# |Japan                         |sensor-pad-3596WIDeCj       |3596     |
# |United Kingdom                |meter-gauge-3613EX8H7JC3w   |3613     |
# |United States                 |device-mac-3615de0LqloM     |3615     |
# |Republic of Korea             |meter-gauge-3631hpAr65H0n   |3631     |
# |Philippines                   |sensor-pad-3660PRAmlUtulC   |3660     |
# |United States                 |device-mac-3681RJ05v        |3681     |
# |United States                 |sensor-pad-3706sJwEf        |3706     |
# |Malaysia                      |meter-gauge-3707GPGbjcN     |3707     |
# |United Kingdom                |sensor-pad-3730FNmTrgc      |3730     |
# |Japan                         |sensor-pad-3738PT7ppDhNn    |3738     |
# |Germany                       |meter-gauge-37390duljxg     |3739     |
# |                              |device-mac-3801uJBAvVpV     |3801     |
# |Brazil                        |sensor-pad-3802L00tjFy      |3802     |
# |Canada                        |sensor-pad-3804AcJlJiA2e    |3804     |
# |Bulgaria                      |sensor-pad-3818KjfiC14U     |3818     |
# |Argentina                     |meter-gauge-3821aL0Ig7lVJ2  |3821     |
# |Hong Kong                     |meter-gauge-3829iNaJv5      |3829     |
# |Czech Republic                |sensor-pad-3842Wv7AuqJuN    |3842     |
# |Australia                     |therm-stick-3845STZLu7j     |3845     |
# |France                        |sensor-pad-3856TqwGdj       |3856     |
# |China                         |device-mac-3867urd8S        |3867     |
# |United States                 |sensor-pad-3870AstDI5Vn     |3870     |
# |                              |meter-gauge-3893aEcLIE      |3893     |
# |Japan                         |device-mac-3897JrybiiZ      |3897     |
# |China                         |meter-gauge-3919qlMH7       |3919     |
# |Latvia                        |sensor-pad-39308G6bFVhGKt   |3930     |
# |United States                 |sensor-pad-3940EmQZa        |3940     |
# |Japan                         |meter-gauge-3941fqIxO       |3941     |
# |United States                 |meter-gauge-3943a8zJA5bq    |3943     |
# |Brazil                        |sensor-pad-39584bnLzpAA7    |3958     |
# |United States                 |meter-gauge-3959xreFpgC     |3959     |
# |Mali                          |device-mac-3993L6hB8dNNX    |3993     |
# |United States                 |sensor-pad-40048coRXshox    |4004     |
# |                              |sensor-pad-4022TT3AW        |4022     |
# |Japan                         |sensor-pad-4026HcHLSfEO     |4026     |
# |China                         |device-mac-4029GByap        |4029     |
# |Republic of Korea             |meter-gauge-40377qRBCM3l    |4037     |
# |United States                 |sensor-pad-4038FumfWEGh     |4038     |
# |Russia                        |sensor-pad-4044C5XiW9BqtS   |4044     |
# |Japan                         |therm-stick-4055VUW2w5beT   |4055     |
# |United Kingdom                |meter-gauge-4079YogxyEIb5g  |4079     |
# |United States                 |meter-gauge-41092hSrk       |4109     |
# |Sweden                        |device-mac-41132IxN8YDf6    |4113     |
# |Republic of Korea             |device-mac-41190DQ5FQ2Ej    |4119     |
# |Cyprus                        |device-mac-4125AusJGr       |4125     |
# |Spain                         |sensor-pad-4136v04Ff73F5    |4136     |
# |Brazil                        |sensor-pad-4156XL2IU        |4156     |
# |United States                 |sensor-pad-4158hoFJW6xA7O   |4158     |
# |Pakistan                      |meter-gauge-4187n76dGPHz4   |4187     |
# |United States                 |sensor-pad-4188k8RoLNUlU    |4188     |
# |Switzerland                   |meter-gauge-4193aSdBIW5hS   |4193     |
# |France                        |sensor-pad-4194i862kjiN36   |4194     |
# |Serbia                        |therm-stick-4205UfTiGQJZv   |4205     |
# |Japan                         |meter-gauge-4207yjtYBSNm    |4207     |
# |United States                 |sensor-pad-4208TIolYQH      |4208     |
# |Pakistan                      |meter-gauge-4223bEcKW0      |4223     |
# |Ukraine                       |sensor-pad-4238Uj7A4n       |4238     |
# |Austria                       |sensor-pad-4268N8x3eBJ5J    |4268     |
# |Taiwan                        |sensor-pad-4282CkzG8hoZd3   |4282     |
# |United States                 |sensor-pad-4292J1BRtaYj     |4292     |
# |Russia                        |sensor-pad-4302fH7oaXWSq    |4302     |
# |United States                 |meter-gauge-4313Qmx1fmWMJ   |4313     |
# |Japan                         |therm-stick-4315DPPJYZueu   |4315     |
# |Macao                         |sensor-pad-4318lkMhEa       |4318     |
# |United States                 |therm-stick-4345U5yKnX9Z    |4345     |
# |Singapore                     |sensor-pad-4350ztDym0y      |4350     |
# |India                         |sensor-pad-4354l8OT95       |4354     |
# |                              |sensor-pad-4362BTX37G3      |4362     |
# |India                         |sensor-pad-4370y9eXCNlIHA   |4370     |
# |United States                 |sensor-pad-4372ya6Hb6       |4372     |
# |Canada                        |therm-stick-4375P9VQFuga    |4375     |
# |Japan                         |sensor-pad-4376PGJZO        |4376     |
# |Denmark                       |meter-gauge-4379UPmmlhJT1K  |4379     |
# |United States                 |sensor-pad-4384PNxLq4       |4384     |
# |France                        |meter-gauge-4421eoqgPzD     |4421     |
# |Israel                        |sensor-pad-4426f5SqzpJU0Q   |4426     |
# |United Kingdom                |device-mac-4431gn3XpQr      |4431     |
# |United States                 |sensor-pad-4438MTuJwT       |4438     |
# |United States                 |sensor-pad-4458pA7IEK1AT    |4458     |
# |Sweden                        |therm-stick-4465CGSy6       |4465     |
# |United Kingdom                |meter-gauge-4481uZIJ64      |4481     |
# |United States                 |sensor-pad-4500iLCMPJslo    |4500     |
# |Canada                        |sensor-pad-4504ib9oii0D     |4504     |
# |United States                 |device-mac-4515FHGY0        |4515     |
# |France                        |sensor-pad-4526aohmAeW      |4526     |
# |United States                 |sensor-pad-4528xuqIxL       |4528     |
# |Kuwait                        |therm-stick-4535L3RW3YdW3G  |4535     |
# |United States                 |device-mac-4539Q4aGiejjXS   |4539     |
# |Honduras                      |sensor-pad-4562a2s7st       |4562     |
# |Iran                          |therm-stick-4565ZV2bs0A9eU  |4565     |
# |United States                 |device-mac-45698kbqNbPu     |4569     |
# |Republic of Korea             |meter-gauge-457724Lod33W    |4577     |
# |France                        |sensor-pad-4586d1yw16Wrvt   |4586     |
# |Russia                        |device-mac-4587mSC3KsalXx   |4587     |
# |Czech Republic                |sensor-pad-46127EXoi        |4612     |
# |France                        |sensor-pad-4614CuEhPeHL     |4614     |
# |United States                 |meter-gauge-46338B3Qn       |4633     |
# |Germany                       |sensor-pad-4646LJkC7Mz      |4646     |
# |United States                 |device-mac-4647KA78o        |4647     |
# |Ukraine                       |therm-stick-4655kJM0f       |4655     |
# |United States                 |sensor-pad-4688Z9P2ASiX     |4688     |
# |Hong Kong                     |meter-gauge-4693Lzyc0zSk    |4693     |
# |Nigeria                       |sensor-pad-4694gFAtW        |4694     |
# |Russia                        |sensor-pad-4696H3Ud10r      |4696     |
# |United States                 |device-mac-4701zcOJIsW      |4701     |
# |Chile                         |device-mac-4707vm4OMXhDAQ   |4707     |
# |United States                 |sensor-pad-4720IPizGS6om    |4720     |
# |United States                 |sensor-pad-4722RvwC5        |4722     |
# |United States                 |meter-gauge-4723xbFj46      |4723     |
# |United States                 |sensor-pad-4740EyNs0cTLV    |4740     |
# |United States                 |therm-stick-4745L2u4rLpzgL  |4745     |
# |United States                 |device-mac-4755aLta6NH      |4755     |
# |Bermuda                       |meter-gauge-4769I4jH9W1V    |4769     |
# |Germany                       |sensor-pad-477261rHct       |4772     |
# |United Kingdom                |meter-gauge-47770POHDbzToQ  |4777     |
# |United States                 |meter-gauge-4801qrCFJG5B    |4801     |
# |Spain                         |meter-gauge-4817bk6Tk       |4817     |
# |Spain                         |sensor-pad-4822WLBFahbJ     |4822     |
# |United States                 |sensor-pad-4828S525Q08uKM   |4828     |
# |Taiwan                        |sensor-pad-48382XTjF6TXu    |4838     |
# |United States                 |device-mac-4851awdcmn       |4851     |
# |United States                 |sensor-pad-4868dPi6hoKk     |4868     |
# |Japan                         |sensor-pad-4878PSxAyCI      |4878     |
# |United Kingdom                |meter-gauge-4883656pYxzeu   |4883     |
# |France                        |device-mac-4887pLe6GA8Y     |4887     |
# |Canada                        |sensor-pad-4888dUMKYJbs4w   |4888     |
# |France                        |device-mac-48997W4Tfg       |4899     |
# |China                         |sensor-pad-4910PfF1I50F7    |4910     |
# |United States                 |sensor-pad-4912IRuwLg8W     |4912     |
# |Spain                         |sensor-pad-4920P6SQt        |4920     |
# |United States                 |meter-gauge-4927mGayoO      |4927     |
# |United States                 |sensor-pad-4930uONkPGI3SH   |4930     |
# |United States                 |sensor-pad-4934rgsmcflaP    |4934     |
# |Singapore                     |sensor-pad-4950ENRZqyKrHn   |4950     |
# |Brazil                        |sensor-pad-4952Dx0l11aIBB   |4952     |
# |United States                 |sensor-pad-4972YN9NC        |4972     |
# |United States                 |sensor-pad-4974i6RIySuV     |4974     |
# |Italy                         |meter-gauge-4999gtXlGEr70X  |4999     |
# |Spain                         |sensor-pad-5028K6lgPKiHS    |5028     |
# |Japan                         |therm-stick-5035efnUx3Gv    |5035     |
# |Japan                         |meter-gauge-5041VUYuV       |5041     |
# |United States                 |device-mac-504386HHSn       |5043     |
# |Republic of Korea             |meter-gauge-5057kPjn2hPNV9  |5057     |
# |United Kingdom                |sensor-pad-508024IMBSjZ4n   |5080     |
# |China                         |device-mac-50915FLrht       |5091     |
# |United States                 |device-mac-5103COSb6v       |5103     |
# |Bulgaria                      |sensor-pad-5124zcB7DL3kCN   |5124     |
# |France                        |sensor-pad-5134vc9ED        |5134     |
# |Japan                         |device-mac-5139PYhrbV2      |5139     |
# |China                         |device-mac-5157LqVQg740     |5157     |
# |United States                 |sensor-pad-51580E98YTn      |5158     |
# |Malaysia                      |meter-gauge-5159TFgjq       |5159     |
# |Poland                        |therm-stick-5165eLwA5m      |5165     |
# |United States                 |sensor-pad-5166M72bLJ       |5166     |
# |United States                 |sensor-pad-5180Lu4Jt8NgB    |5180     |
# |Brazil                        |device-mac-5187gubIHn       |5187     |
# |United States                 |device-mac-5205segYIBvu8n   |5205     |
# |United States                 |sensor-pad-5210ytlDw        |5210     |
# |Republic of Korea             |device-mac-5211wj4HLS       |5211     |
# |Hong Kong                     |meter-gauge-5213GdsfHn      |5213     |
# |United States                 |therm-stick-5215GTDo7qbyu   |5215     |
# |Italy                         |sensor-pad-5226xNTUE2uj     |5226     |
# |Republic of Korea             |sensor-pad-5228wVKTCmoHI    |5228     |
# |Brazil                        |meter-gauge-5233606NZ       |5233     |
# |Lebanon                       |sensor-pad-5248M1aD8        |5248     |
# |Macao                         |sensor-pad-5258uFZjtfNLU    |5258     |
# |Germany                       |sensor-pad-5272EA7lHKn      |5272     |
# |Thailand                      |meter-gauge-527303BKlq      |5273     |
# |Netherlands                   |sensor-pad-5274fSQB4QL0S    |5274     |
# |United States                 |device-mac-5289eYylwEgV     |5289     |
# |United States                 |meter-gauge-5291soLHc1MT    |5291     |
# |United States                 |sensor-pad-53047RHOW11X     |5304     |
# |Germany                       |device-mac-5307cmQyIeBVwa   |5307     |
# |Switzerland                   |sensor-pad-5314ALYu7UXqtS   |5314     |
# |United States                 |sensor-pad-53166bc4yE1A     |5316     |
# |United States                 |therm-stick-5345jI8ws652    |5345     |
# |United States                 |sensor-pad-5400ZCXAqHEi     |5400     |
# |Germany                       |device-mac-5403hDQzh        |5403     |
# |China                         |sensor-pad-54044GW8K3T0Gl   |5404     |
# |United States                 |device-mac-5415P5K1l6FVx    |5415     |
# |United States                 |sensor-pad-5422mo4Xy8XJ5    |5422     |
# |France                        |meter-gauge-5423GLDgboc     |5423     |
# |China                         |device-mac-5451RepebV       |5451     |
# |Sweden                        |sensor-pad-54644PD3PwGal    |5464     |
# |United States                 |therm-stick-5485eUMCkb1     |5485     |
# |Sweden                        |device-mac-5493cbkdnu       |5493     |
# |United States                 |sensor-pad-5498oR58H        |5498     |
# |United States                 |device-mac-554737CJi        |5547     |
# |Japan                         |sensor-pad-5552IgbfSzv      |5552     |
# |Republic of Korea             |device-mac-5559VG1XJmE      |5559     |
# |Russia                        |meter-gauge-5581Oe92SWv     |5581     |
# |United Kingdom                |sensor-pad-55883d3Vf9S      |5588     |
# |Hong Kong                     |sensor-pad-5592eErsx798Y    |5592     |
# |United States                 |meter-gauge-5603WxX3xenz    |5603     |
# |Japan                         |meter-gauge-5609pbUs5Kd     |5609     |
# |Republic of Korea             |meter-gauge-5623MSHDZN      |5623     |
# |Republic of Korea             |meter-gauge-5627nUpv19wzpg  |5627     |
# |United States                 |meter-gauge-5689T0XBBFdaff  |5689     |
# |Taiwan                        |sensor-pad-5690a45zPKh5OW   |5690     |
# |Canada                        |therm-stick-5705CaJ08k1Xxy  |5705     |
# |Germany                       |sensor-pad-5716DRcGcb       |5716     |
# |China                         |meter-gauge-5729Uw1sIs      |5729     |
# |Israel                        |device-mac-5739VDE2e        |5739     |
# |Singapore                     |meter-gauge-5743Us8tjQYE0   |5743     |
# |                              |sensor-pad-5772eWLG3qs      |5772     |
# |United States                 |sensor-pad-5774oH6LBXGJz    |5774     |
# |United States                 |sensor-pad-578810sdD2L2hI   |5788     |
# |Germany                       |sensor-pad-5792IAFkZms3c    |5792     |
# |Indonesia                     |sensor-pad-5794qbVsD        |5794     |
# |Germany                       |meter-gauge-5813QgDf2       |5813     |
# |Norway                        |device-mac-5823NDJfcrQOti   |5823     |
# |Japan                         |meter-gauge-5839cBzlMWff    |5839     |
# |United States                 |sensor-pad-5840Q95vMyx      |5840     |
# |Netherlands                   |meter-gauge-58613xhFtPUHDe  |5861     |
# |China                         |meter-gauge-5867ZRopYJaDX   |5867     |
# |United States                 |sensor-pad-5870f49PsxjaRo   |5870     |
# |Netherlands                   |device-mac-5871YykX3dU      |5871     |
# |United States                 |meter-gauge-5881RPS8EzE     |5881     |
# |United States                 |sensor-pad-5892KfSgp3qq     |5892     |
# |United States                 |sensor-pad-5896HY0FCv9ZtE   |5896     |
# |China                         |sensor-pad-591486ddU        |5914     |
# |Egypt                         |sensor-pad-5924Y3duTUjDA3   |5924     |
# |Hong Kong                     |sensor-pad-5944ZieFm        |5944     |
# |China                         |therm-stick-5945VltjKdmc    |5945     |
# |United Kingdom                |meter-gauge-5953pIL2ZnCE    |5953     |
# |United States                 |device-mac-5961MyJnj        |5961     |
# |United States                 |therm-stick-5975EzdTrtRi8A  |5975     |
# |United States                 |sensor-pad-5994sZjyJ5c      |5994     |
# |Poland                        |sensor-pad-6014WOYFyXxE     |6014     |
# |Taiwan                        |sensor-pad-6016GNPosumTyA   |6016     |
# |France                        |meter-gauge-6017qy5N68uxgR  |6017     |
# |United States                 |sensor-pad-6018xe6tmow      |6018     |
# |Romania                       |meter-gauge-6029G3OVEMDu    |6029     |
# |Canada                        |meter-gauge-6031uLI9DPq     |6031     |
# |Romania                       |sensor-pad-6038Vjmv0WLZEr   |6038     |
# |China                         |meter-gauge-6041o5bGhk      |6041     |
# |United States                 |sensor-pad-60440U8H6Aq      |6044     |
# |United States                 |device-mac-6063Jcx4PSYnY    |6063     |
# |United Kingdom                |device-mac-6075SXQAcBlTq    |6075     |
# |Germany                       |sensor-pad-6092azDKFTln     |6092     |
# |Canada                        |therm-stick-6095INxehh      |6095     |
# |United States                 |sensor-pad-6096JGpjL        |6096     |
# |Denmark                       |device-mac-6105Xk12XHZqSt   |6105     |
# |Japan                         |sensor-pad-61163yRGGi       |6116     |
# |United States                 |device-mac-61173XWusq       |6117     |
# |New Zealand                   |meter-gauge-6131QNrUwIN     |6131     |
# |United States                 |device-mac-6135eXevR        |6135     |
# |France                        |sensor-pad-6136Yl7xd5       |6136     |
# |Japan                         |meter-gauge-6137zihJmJc     |6137     |
# |Poland                        |therm-stick-6145x62YpbvdjL  |6145     |
# |Russia                        |sensor-pad-6146Da6wWX       |6146     |
# |France                        |device-mac-6147UOUmZh       |6147     |
# |United States                 |meter-gauge-61610Lakv6zb    |6161     |
# |United States                 |meter-gauge-61672kahGVx     |6167     |
# |Republic of Korea             |sensor-pad-6190SaawuCN7d    |6190     |
# |Republic of Korea             |meter-gauge-61930eZTkXWDau  |6193     |
# |Mauritius                     |device-mac-6195Ovzwq        |6195     |
# |Sweden                        |meter-gauge-61977rmx4ffma   |6197     |
# |United States                 |sensor-pad-6214vvfFvO       |6214     |
# |China                         |sensor-pad-62261qyBBg       |6226     |
# |Norway                        |device-mac-6237C9rCuu       |6237     |
# |China                         |meter-gauge-6241spsM6       |6241     |
# |United States                 |sensor-pad-62442cWVS5OG     |6244     |
# |United States                 |device-mac-6249s0EreJ5K     |6249     |
# |United Kingdom                |sensor-pad-62541JmqzjEgE    |6254     |
# |United States                 |sensor-pad-6280D1ZzGfTjd    |6280     |
# |Japan                         |meter-gauge-6283oEwiBuPIq0  |6283     |
# |Germany                       |therm-stick-6305uA59imhUqF  |6305     |
# |China                         |meter-gauge-6307ovm32aub    |6307     |
# |United States                 |sensor-pad-6308lfczr        |6308     |
# |China                         |sensor-pad-63287OInEUq      |6328     |
# |Australia                     |device-mac-6339MJdRdSs      |6339     |
# |United Arab Emirates          |meter-gauge-6353UtwwhgmxSp  |6353     |
# |Romania                       |therm-stick-6355YidPR1      |6355     |
# |Japan                         |sensor-pad-6356ZXZpHqg      |6356     |
# |Austria                       |therm-stick-6365EukE9nw     |6365     |
# |United States                 |device-mac-6369ANA7IwpGQ    |6369     |
# |United States                 |sensor-pad-637094tWm        |6370     |
# |United States                 |sensor-pad-63760MbAbYs2u    |6376     |
# |Japan                         |meter-gauge-6403d0Bt5       |6403     |
# |United States                 |sensor-pad-6406tXbsSJm      |6406     |
# |Russia                        |therm-stick-6415nNpdOgAx    |6415     |
# |China                         |sensor-pad-6454R6E4mM6ntW   |6454     |
# |United States                 |sensor-pad-64569dpNHvm7K    |6456     |
# |United States                 |meter-gauge-6467V0WqZ       |6467     |
# |United States                 |meter-gauge-6473ttktWS8fv   |6473     |
# |Australia                     |meter-gauge-6497XlGxT       |6497     |
# |United States                 |sensor-pad-6498cuT33AkAU    |6498     |
# |Republic of Korea             |sensor-pad-6500Qw2ZF        |6500     |
# |United States                 |therm-stick-65051zy8HSFZ0j  |6505     |
# |Germany                       |sensor-pad-6540Tuk0m        |6540     |
# |Canada                        |device-mac-6543J7wkbKfT5    |6543     |
# |Poland                        |sensor-pad-6544DA2nKuhMC    |6544     |
# |Russia                        |sensor-pad-6554Pqb42Hf      |6554     |
# |Republic of Korea             |sensor-pad-6594m91GMQZm1    |6594     |
# |China                         |therm-stick-6605Nas5KdcXiv  |6605     |
# |United States                 |sensor-pad-6614Pe7aqFF      |6614     |
# |Poland                        |device-mac-6627hRZAcJs7uS   |6627     |
# |Japan                         |sensor-pad-6638A0vmUEsw     |6638     |
# |United States                 |sensor-pad-6648O9AClShHN    |6648     |
# |India                         |sensor-pad-6650KjjJIkTBn    |6650     |
# |Canada                        |therm-stick-66554bQiKDfg    |6655     |
# |Latvia                        |sensor-pad-66682lKAv        |6668     |
# |Argentina                     |device-mac-6669wcwq8T8GIl   |6669     |
# |Russia                        |meter-gauge-6673wN4IMGIiA   |6673     |
# |Spain                         |meter-gauge-66771jbcFvQ6z3  |6677     |
# |Argentina                     |sensor-pad-6692iWV2hjAyVW   |6692     |
# ...
# |Germany                       |sensor-pad-196162GUXN4uO6K  |196162   |
# |Spain                         |sensor-pad-196164w1Bhyx1KD  |196164   |
# |United States                 |therm-stick-196175iSK8JGbY  |196175   |
# |United States                 |meter-gauge-196181nb9hKC4o1 |196181   |
# |Mexico                        |device-mac-196185AXVCmGVb   |196185   |
# |United States                 |meter-gauge-19620758yppxXHG |196207   |
# |China                         |device-mac-196209t1y8jLT    |196209   |
# |United States                 |sensor-pad-196214msGQBQ     |196214   |
# |Mozambique                    |device-mac-19623323z2Ur7x   |196233   |
# |United States                 |meter-gauge-1962470MEIJYRIyI|196247   |
# |United States                 |device-mac-196257WUpLQOw    |196257   |
# |Italy                         |sensor-pad-196262niIobR     |196262   |
# |United States                 |device-mac-196263MtjETp7zW  |196263   |
# |Sweden                        |sensor-pad-1962840Pu1MF     |196284   |
# |Japan                         |sensor-pad-196308MMqlQ      |196308   |
# |India                         |sensor-pad-1963101x3wW      |196310   |
# |Russia                        |sensor-pad-196316seeKIgt51C |196316   |
# |United States                 |sensor-pad-196324h23GQh9z0V |196324   |
# |Spain                         |sensor-pad-196326PO8mN4hK8  |196326   |
# |Republic of Korea             |sensor-pad-196352H6dawRERZ  |196352   |
# |United States                 |sensor-pad-196358EnipE1R    |196358   |
# |United States                 |meter-gauge-196361G7D0L     |196361   |
# |United States                 |meter-gauge-196367MGf14E53z |196367   |
# |Philippines                   |device-mac-196371AuPlWBtQ   |196371   |
# |United States                 |sensor-pad-196372sTsG5      |196372   |
# |Thailand                      |meter-gauge-196423HddHx9qzoP|196423   |
# |United States                 |meter-gauge-196429hDH8Tw    |196429   |
# |United States                 |meter-gauge-1964396t8eR0eq7W|196439   |
# |United States                 |sensor-pad-196442fCHp9k3o   |196442   |
# |Russia                        |device-mac-196443gF05pKniXN |196443   |
# |Denmark                       |device-mac-196485bmP4lk     |196485   |
# |China                         |meter-gauge-196489JQaI3     |196489   |
# |Japan                         |meter-gauge-196493XCq51TF   |196493   |
# |Chile                         |therm-stick-196495cWHeOqopY |196495   |
# |United States                 |sensor-pad-196508JiawB5     |196508   |
# |Spain                         |meter-gauge-196529voo2sRmWUn|196529   |
# |Italy                         |device-mac-196533em0xxyFW   |196533   |
# |Bulgaria                      |sensor-pad-196544yIsAuQmE   |196544   |
# |Taiwan                        |device-mac-196551HOpJztooi  |196551   |
# |                              |therm-stick-196555G9IZkUf   |196555   |
# |United States                 |device-mac-196569rake5HJ    |196569   |
# |Brazil                        |sensor-pad-196570ZRoYWQNKi  |196570   |
# |Australia                     |meter-gauge-196571zEaIa1    |196571   |
# |Canada                        |meter-gauge-196573mhU8AqEKT |196573   |
# |Brazil                        |sensor-pad-196576Jfaamf15H  |196576   |
# |China                         |sensor-pad-196580ipwLdsE    |196580   |
# |United States                 |sensor-pad-196594PyjHmtbxge |196594   |
# |United States                 |device-mac-1965999JgSU10G0  |196599   |
# |United States                 |sensor-pad-196600S1VFqI     |196600   |
# |United States                 |sensor-pad-19660283qxkD5WN  |196602   |
# |Japan                         |sensor-pad-196604j6I8pyn    |196604   |
# |United Kingdom                |sensor-pad-196606uAcGc      |196606   |
# |United States                 |meter-gauge-196627jhWvNeM3  |196627   |
# |Japan                         |sensor-pad-196630ApDk81m    |196630   |
# |United States                 |meter-gauge-196633zFMlBD4Ui |196633   |
# |United States                 |device-mac-196677Aywfylc10w |196677   |
# |Japan                         |therm-stick-196685zsvaT     |196685   |
# |China                         |meter-gauge-196687Wfr0oTN   |196687   |
# |France                        |sensor-pad-196688wEB2qfGTMl |196688   |
# |Tanzania                      |sensor-pad-196694ZS1Ia      |196694   |
# |Croatia                       |meter-gauge-196697iCR3cs6   |196697   |
# |France                        |sensor-pad-196698csECQcN5gE |196698   |
# |United Kingdom                |device-mac-196701VPMOq      |196701   |
# |Japan                         |meter-gauge-196709gmuDX     |196709   |
# |Germany                       |sensor-pad-196728fFbbp      |196728   |
# |Republic of Korea             |sensor-pad-196748Ba0UBo3yuB |196748   |
# |United States                 |meter-gauge-196757jc4rb1    |196757   |
# |United States                 |sensor-pad-196766jW2IJ      |196766   |
# |United States                 |device-mac-196767oWPyIF     |196767   |
# |Japan                         |sensor-pad-196768AeFb6SnLI6 |196768   |
# |United Kingdom                |device-mac-196779B2VuZa1eo  |196779   |
# |France                        |sensor-pad-1967840rUch      |196784   |
# |Australia                     |device-mac-1967975Rjmr      |196797   |
# |United States                 |sensor-pad-1968043OXhu8r9wl |196804   |
# |United States                 |therm-stick-1968053ENxlHh3SB|196805   |
# |United States                 |meter-gauge-196811YaouSSTE  |196811   |
# |Mexico                        |sensor-pad-196812kAXaPP7Jg  |196812   |
# |Ukraine                       |sensor-pad-196820wIHBZeyGj  |196820   |
# |China                         |sensor-pad-1968387udv389    |196838   |
# |United States                 |sensor-pad-1968407fvQm1     |196840   |
# |United States                 |sensor-pad-196854GRsoX      |196854   |
# |Pakistan                      |sensor-pad-196860qUOBj8bxT  |196860   |
# |Russia                        |sensor-pad-196896GfJr8S     |196896   |
# |Russia                        |meter-gauge-196897hc6NfO    |196897   |
# |Republic of Korea             |device-mac-1968996hmkSxG    |196899   |
# |China                         |meter-gauge-196909BIRY4h    |196909   |
# |Philippines                   |sensor-pad-196910hLKzNiBvEV |196910   |
# |Spain                         |meter-gauge-196913ozwUu     |196913   |
# |United States                 |device-mac-196917FBTBgPTq   |196917   |
# |Italy                         |meter-gauge-19691950QfW9t   |196919   |
# |United States                 |sensor-pad-196924FKxXiu     |196924   |
# |                              |meter-gauge-196927ziHEhS    |196927   |
# |Australia                     |sensor-pad-1969289Rt53KT    |196928   |
# |United States                 |device-mac-196929IbasjU1ccC |196929   |
# |China                         |meter-gauge-196931ZrciKsi   |196931   |
# |United Kingdom                |meter-gauge-1969372FVrvTZ4I |196937   |
# |United States                 |device-mac-196941WjkQEs     |196941   |
# |Republic of Korea             |sensor-pad-196954ssa15Pxjlo |196954   |
# |Spain                         |sensor-pad-196960nOlMG      |196960   |
# |India                         |meter-gauge-196987tHtmY     |196987   |
# |Mexico                        |sensor-pad-196996JBW6FIhjn  |196996   |
# |China                         |sensor-pad-197040cQ6xouR    |197040   |
# |Republic of Korea             |device-mac-197049dtVKec     |197049   |
# |Russia                        |meter-gauge-197051zVqgb     |197051   |
# |United States                 |meter-gauge-197053Lu8R3tyeY |197053   |
# |South Africa                  |sensor-pad-197056PKhWjWrH   |197056   |
# |Ukraine                       |device-mac-197061j9ijLxX    |197061   |
# |Japan                         |therm-stick-1970659MTVBa    |197065   |
# |Israel                        |meter-gauge-1971017VlaYN6   |197101   |
# |United States                 |sensor-pad-197104VqVhaT     |197104   |
# |United States                 |meter-gauge-1971073tLJtJ    |197107   |
# |United States                 |sensor-pad-19712202ZPm3eUt7 |197122   |
# |Republic of Korea             |sensor-pad-197152McEzxGXeW2 |197152   |
# |United States                 |meter-gauge-197153yeweF     |197153   |
# |United States                 |device-mac-197193wglynNIs   |197193   |
# |United States                 |meter-gauge-197231jDSG6G    |197231   |
# |Japan                         |sensor-pad-1972344WGKdJ8k   |197234   |
# |Antigua and Barbuda           |sensor-pad-197248zgYRYku    |197248   |
# |Nigeria                       |meter-gauge-197261Qj84x3754 |197261   |
# |Argentina                     |sensor-pad-197266MtupLhRy   |197266   |
# |United States                 |sensor-pad-197268KcLbX      |197268   |
# |United States                 |meter-gauge-197281Zl2V2G    |197281   |
# |United States                 |meter-gauge-197327bgFPd     |197327   |
# |Republic of Korea             |sensor-pad-197332DurIGJe4X  |197332   |
# |Japan                         |sensor-pad-197334hgOhqzDxEB |197334   |
# |China                         |sensor-pad-197336bQmy6bxUi  |197336   |
# |Pakistan                      |meter-gauge-197339gNFLNJbKs |197339   |
# |United States                 |device-mac-197343pa5BXTMmKj |197343   |
# |Argentina                     |device-mac-197355VdrM65O9K  |197355   |
# |Germany                       |sensor-pad-197366tVakuKSHen |197366   |
# |Taiwan                        |device-mac-197367kUOz4      |197367   |
# |United States                 |sensor-pad-1973728EuKGimfAZ |197372   |
# |Russia                        |device-mac-197373NuitRE     |197373   |
# |Japan                         |meter-gauge-197381sciap5    |197381   |
# |Thailand                      |sensor-pad-197408vZGrEz     |197408   |
# |United States                 |sensor-pad-1974104PmtvR8W0n |197410   |
# |Republic of Korea             |sensor-pad-197416IJyIl4     |197416   |
# |Singapore                     |meter-gauge-197417Md9NRQes  |197417   |
# |Poland                        |sensor-pad-1974227wHGEyk    |197422   |
# |Hong Kong                     |sensor-pad-197424Pn4TcH     |197424   |
# |United Kingdom                |sensor-pad-197438Kh8ftDi    |197438   |
# |Spain                         |device-mac-197457Sdfz9mU    |197457   |
# |Switzerland                   |meter-gauge-197461vALTpx4h  |197461   |
# |United States                 |therm-stick-1974653lrEa     |197465   |
# |Republic of Korea             |sensor-pad-1974661oiHhikc4Z |197466   |
# |United States                 |meter-gauge-197483MeuSsu2LI |197483   |
# |United Kingdom                |therm-stick-197485e2LPgz    |197485   |
# |United States                 |sensor-pad-1974923HUULkSiuw |197492   |
# |Japan                         |device-mac-1974934VWUz3fp9  |197493   |
# |Japan                         |device-mac-197511v7JMt      |197511   |
# |Åland                         |sensor-pad-197516kgrtgG0JJh |197516   |
# |United States                 |sensor-pad-1975182LcjqH     |197518   |
# |United States                 |sensor-pad-197522n8ypMlJMi  |197522   |
# |Malaysia                      |sensor-pad-197524KKRelha    |197524   |
# |United States                 |meter-gauge-197551QPqaq8    |197551   |
# |Japan                         |sensor-pad-197560NsGFM      |197560   |
# |Japan                         |sensor-pad-197564zxhoxZyyE7 |197564   |
# |Japan                         |device-mac-197565z2HbL      |197565   |
# |United States                 |sensor-pad-197566jQyQz      |197566   |
# |Sweden                        |meter-gauge-197581fi2NHbi   |197581   |
# |United States                 |sensor-pad-197588GAkcVpsDcn |197588   |
# |France                        |sensor-pad-197594hC8Jq6C7Jm |197594   |
# |United States                 |sensor-pad-197598Rh7THUHI   |197598   |
# |Egypt                         |device-mac-197625KZHu8      |197625   |
# |Pakistan                      |sensor-pad-197626TZwPUqppki |197626   |
# |United States                 |device-mac-197637GCit4      |197637   |
# |United States                 |device-mac-197655HBRFyVOa   |197655   |
# |China                         |device-mac-197673OoavgtAyp  |197673   |
# |United States                 |sensor-pad-197690sjBTyqP    |197690   |
# |Ireland                       |sensor-pad-197694ovNkM      |197694   |
# |Malaysia                      |device-mac-19770321iV2Z     |197703   |
# |China                         |sensor-pad-197738cLsScCj5nV |197738   |
# |India                         |sensor-pad-197754FGJgJvYjGR |197754   |
# |United States                 |sensor-pad-197772sfewYH     |197772   |
# |United States                 |sensor-pad-1977761Qp9dK     |197776   |
# |United States                 |meter-gauge-197783c5CRuFJwxA|197783   |
# |China                         |meter-gauge-1977915x5ibW7   |197791   |
# |United States                 |therm-stick-1977952LvcfL8kC |197795   |
# |United States                 |meter-gauge-1978210NnoG5    |197821   |
# |Denmark                       |therm-stick-1978253mvarnm   |197825   |
# |United States                 |therm-stick-197845WQE4Niw   |197845   |
# |Ecuador                       |sensor-pad-197848adLKYWzwvW |197848   |
# |United States                 |meter-gauge-197849X2S6Bsx   |197849   |
# |United Kingdom                |sensor-pad-197850kWZY2Mm5bI |197850   |
# |Hong Kong                     |device-mac-197853SLAo6rC    |197853   |
# |United States                 |sensor-pad-197854VRdHNwngO  |197854   |
# |United States                 |meter-gauge-197869GpIZJP2f  |197869   |
# |Puerto Rico                   |sensor-pad-197876MEDwIz     |197876   |
# |Canada                        |sensor-pad-197888J5GqSj0Q   |197888   |
# |Germany                       |meter-gauge-1978934zvWnSV   |197893   |
# |Germany                       |device-mac-197895AogFC1     |197895   |
# |United States                 |meter-gauge-197903TYhvqk52  |197903   |
# |United States                 |sensor-pad-197904LDf7GX     |197904   |
# |China                         |sensor-pad-197908YTOPduEqJ  |197908   |
# |Canada                        |therm-stick-197935OmpauX84Pb|197935   |
# |Turkey                        |sensor-pad-197940NZ879Iag   |197940   |
# |United States                 |sensor-pad-197942gFvuUQr    |197942   |
# |United States                 |meter-gauge-197969A55TavO   |197969   |
# |Ukraine                       |device-mac-197997APSKZRViIU |197997   |
# |Mexico                        |sensor-pad-198000uU5FU      |198000   |
# |United States                 |meter-gauge-198001JoySgiet  |198001   |
# |South Africa                  |sensor-pad-198002msPuQ      |198002   |
# |United States                 |sensor-pad-1980064EZVMw     |198006   |
# |Estonia                       |sensor-pad-198018rxYlD1     |198018   |
# |Japan                         |meter-gauge-1980318JuIOxNDuX|198031   |
# |China                         |sensor-pad-1980324MSeLW     |198032   |
# |Canada                        |therm-stick-198035H165s     |198035   |
# |Switzerland                   |sensor-pad-198044syFdMtSDHH |198044   |
# |Ireland                       |meter-gauge-1980596y49Vynlbk|198059   |
# |Italy                         |device-mac-198063LovGbbtxZN |198063   |
# |Sweden                        |sensor-pad-19807211VdlAm    |198072   |
# |United States                 |device-mac-1980752TXWWDvkDR |198075   |
# |United States                 |meter-gauge-198077n3mI72fpYl|198077   |
# |Hungary                       |sensor-pad-198080HGwHSZYw   |198080   |
# |Switzerland                   |meter-gauge-198091rq5n6k    |198091   |
# |Poland                        |sensor-pad-1980960Zv1vq     |198096   |
# |United States                 |meter-gauge-198107dLHf9jLT  |198107   |
# |United States                 |device-mac-198111VqSj5GrOSZ |198111   |
# |Japan                         |sensor-pad-198116w62Jre3LNF |198116   |
# |Germany                       |sensor-pad-198144xoq0vNQCH  |198144   |
# |Poland                        |sensor-pad-198164Ndlyvs0r9C |198164   |
# +------------------------------+----------------------------+---------+
